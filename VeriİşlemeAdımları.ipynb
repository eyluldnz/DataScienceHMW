# %%
class Information([]):
    def __init__(self):
        print()
        
    def info():
        print(column,Non-Null Count,Dtypes)
        
    def dataDescribe():
        print(mean,std,minvalue,maxvalue...)
        
class ManipulationSteps(self,data...):
    
    def __init__(self):
        print()
        
    def DataManipulation():
        
class Visualization:
    
    def __init__(self):
        print()
    
    def visualize(self,data,x,y...):
        
class Preprocessing():
    
    def __init__(self):
        print()
        
    def Standardization():
        
    def Categorical_Input_Convert():
        LabelEncoding or Dummies
    
    def FeatureSelections():
        Confusion Matrix, Corr. Matrix

class ModelOperation:
    
    def __init__(self):
        print()
    
    def createModel():
    
    def crossValidation():
    
    def gridSearch():
        
    def modelFitAndPredict():
    
class AnalysisOfResults():
    
     def __init__(self):
        print()
    
    def analysisResults():
        print(accuracy,precision,recall,R2,F1-Score,support)
